# %% [markdown]
# <a href="https://colab.research.google.com/github/SanudaTharin/MoviePredictions/blob/main/IMdB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('IMdB_India_Top250.csv')
df.head()
# Out:
#          Movie name  Year of release        Watch  hour   Rating Ratedby  \
# 0         12th Fail             2023  2 hours 27 minutes     8.9    126K
# 1          Gol Maal             1979            2 hours      8.5     20K
# 2          Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu             1959   1 hour 45 minutes     8.4     17K
#
#        Film Industry             Genre              Director  \
# 0  Bollywood (Hindi)  Drama, Biography    Vidhu Vinod Chopra
# 1  Bollywood (Hindi)            Comedy  Hrishikesh Mukherjee
# 2  Kollywood (Tamil)      Crime, Drama   Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama           Mani Ratnam
# 4     Bengali Cinema             Drama          Satyajit Ray
#
#   Box office collection  User reviews                        Awards  \
# 0           $138,288.00           945      23 wins & 32 nominations
# ...

# %%
df.shape
# Out:
# (250, 13)

# %%
df.isna().sum()
# Out:
# Movie name               0
# Year of release          0
# Watch  hour              0
# Rating                   0
# Ratedby                  0
# Film Industry            0
# Genre                    0
# Director                 0
# Box office collection    0
# User reviews             0
# Awards                   0
# Description              0
# Streaming platform       0
# dtype: int64

# %%
duplicates = df.duplicated(keep=False)
dup_rows = df[duplicates]

print(dup_rows)
# Out:
# Empty DataFrame
# Columns: [Movie name, Year of release, Watch  hour , Rating, Ratedby, Film Industry, Genre, Director, Box office collection, User reviews, Awards, Description, Streaming platform]
# Index: []

# %%
df.replace('NIL',np.nan, inplace=True)

# %%
df.isna().sum()
# Out:
# Movie name               0
# Year of release          0
# Watch  hour              0
# Rating                   0
# Ratedby                  0
# Film Industry            0
# Genre                    0
# Director                 0
# Box office collection    0
# User reviews             0
# Awards                   9
# Description              0
# Streaming platform       0
# dtype: int64

# %%
df.head()
# Out:
#          Movie name  Year of release        Watch  hour   Rating Ratedby  \
# 0         12th Fail             2023  2 hours 27 minutes     8.9    126K
# 1          Gol Maal             1979            2 hours      8.5     20K
# 2          Maharaja             2024  2 hours 30 minutes     8.6     37K
# 3           Nayakan             1987  2 hours 25 minutes     8.7     25K
# 4  The World of Apu             1959   1 hour 45 minutes     8.4     17K
#
#        Film Industry             Genre              Director  \
# 0  Bollywood (Hindi)  Drama, Biography    Vidhu Vinod Chopra
# 1  Bollywood (Hindi)            Comedy  Hrishikesh Mukherjee
# 2  Kollywood (Tamil)      Crime, Drama   Nithilan Saminathan
# 3  Kollywood (Tamil)      Crime, Drama           Mani Ratnam
# 4     Bengali Cinema             Drama          Satyajit Ray
#
#   Box office collection  User reviews                        Awards  \
# 0           $138,288.00           945      23 wins & 32 nominations
# ...

# %%
df['Box office collection'] = df['Box office collection'].astype(str)
df.replace('NIL',np.nan,inplace=True)
df.isna().sum()
# Out:
# Movie name               0
# Year of release          0
# Watch  hour              0
# Rating                   0
# Ratedby                  0
# Film Industry            0
# Genre                    0
# Director                 0
# Box office collection    0
# User reviews             0
# Awards                   9
# Description              0
# Streaming platform       0
# dtype: int64

# %%
df.dtypes
# Out:
# Movie name                object
# Year of release            int64
# Watch  hour               object
# Rating                   float64
# Ratedby                   object
# Film Industry             object
# Genre                     object
# Director                  object
# Box office collection     object
# User reviews               int64
# Awards                    object
# Description               object
# Streaming platform        object
# dtype: object

# %%
df.replace('$','',inplace=True)

# %%
df
# Out:
#                    Movie name  Year of release        Watch  hour   Rating  \
# 0                   12th Fail             2023  2 hours 27 minutes     8.9
# 1                    Gol Maal             1979            2 hours      8.5
# 2                    Maharaja             2024  2 hours 30 minutes     8.6
# 3                     Nayakan             1987  2 hours 25 minutes     8.7
# 4            The World of Apu             1959   1 hour 45 minutes     8.4
# ..                        ...              ...                 ...     ...
# 245                 Mr. India             1987  2 hours 59 minutes     7.7
# 246  Hazaaron Khwaishein Aisi             2003            2 hours      7.9
# 247                    Ghilli             2004  2 hours 40 minutes     8.1
# 248  Mukundan Unni Associates             2022   2 hours 8 minutes     7.9
# 249                Happy Days             2007  2 hours 33 minutes     7.9
#
#     Ratedby          Film Industry                     Genre  \
# ...

# %%
df['Box office collection'] = df['Box office collection'].str.replace('$','')
df['Ratedby'] = df['Ratedby'].str.replace('K','')
df['Box office collection'] = df['Box office collection'].replace('NIL',np.nan)

# %%
df
# Out:
#                    Movie name  Year of release        Watch  hour   Rating  \
# 0                   12th Fail             2023  2 hours 27 minutes     8.9
# 1                    Gol Maal             1979            2 hours      8.5
# 2                    Maharaja             2024  2 hours 30 minutes     8.6
# 3                     Nayakan             1987  2 hours 25 minutes     8.7
# 4            The World of Apu             1959   1 hour 45 minutes     8.4
# ..                        ...              ...                 ...     ...
# 245                 Mr. India             1987  2 hours 59 minutes     7.7
# 246  Hazaaron Khwaishein Aisi             2003            2 hours      7.9
# 247                    Ghilli             2004  2 hours 40 minutes     8.1
# 248  Mukundan Unni Associates             2022   2 hours 8 minutes     7.9
# 249                Happy Days             2007  2 hours 33 minutes     7.9
#
#     Ratedby          Film Industry                     Genre  \
# ...

# %%
import re

def convert_to_float(duration):
  hours = re.search(r'(\d+)\s*hour',duration)
  minutes = re.search(r'(\d+)\s*minute',duration)

  hours = int(hours.group(1)) if hours else 0
  minutes = int(minutes.group(1)) if minutes else 0

  total_duration = hours + minutes/60
  return total_duration

df['Watch  hour '] = df['Watch  hour '].apply(convert_to_float)

df
# Out:
#                    Movie name  Year of release  Watch  hour   Rating Ratedby  \
# 0                   12th Fail             2023      2.450000     8.9     126
# 1                    Gol Maal             1979      2.000000     8.5      20
# 2                    Maharaja             2024      2.500000     8.6      37
# 3                     Nayakan             1987      2.416667     8.7      25
# 4            The World of Apu             1959      1.750000     8.4      17
# ..                        ...              ...           ...     ...     ...
# 245                 Mr. India             1987      2.983333     7.7      17
# 246  Hazaaron Khwaishein Aisi             2003      2.000000     7.9     5.3
# 247                    Ghilli             2004      2.666667     8.1      17
# 248  Mukundan Unni Associates             2022      2.133333     7.9     6.2
# 249                Happy Days             2007      2.550000     7.9     6.3
#
# ...

# %%
df['Box office collection'] = df['Box office collection'].replace('NIL', np.NaN)

# %%
df
# Out:
#                    Movie name  Year of release  Watch  hour   Rating Ratedby  \
# 0                   12th Fail             2023      2.450000     8.9     126
# 1                    Gol Maal             1979      2.000000     8.5      20
# 2                    Maharaja             2024      2.500000     8.6      37
# 3                     Nayakan             1987      2.416667     8.7      25
# 4            The World of Apu             1959      1.750000     8.4      17
# ..                        ...              ...           ...     ...     ...
# 245                 Mr. India             1987      2.983333     7.7      17
# 246  Hazaaron Khwaishein Aisi             2003      2.000000     7.9     5.3
# 247                    Ghilli             2004      2.666667     8.1      17
# 248  Mukundan Unni Associates             2022      2.133333     7.9     6.2
# 249                Happy Days             2007      2.550000     7.9     6.3
#
# ...

# %%
df.dtypes
# Out:
# Movie name                object
# Year of release            int64
# Watch  hour              float64
# Rating                   float64
# Ratedby                   object
# Film Industry             object
# Genre                     object
# Director                  object
# Box office collection     object
# User reviews               int64
# Awards                    object
# Description               object
# Streaming platform        object
# dtype: object

# %%
df.isna().sum
# Out:
# <bound method DataFrame.sum of      Movie name  Year of release  Watch  hour   Rating  Ratedby  \
# 0         False            False         False   False    False
# 1         False            False         False   False    False
# 2         False            False         False   False    False
# 3         False            False         False   False    False
# 4         False            False         False   False    False
# ..          ...              ...           ...     ...      ...
# 245       False            False         False   False    False
# 246       False            False         False   False    False
# 247       False            False         False   False    False
# 248       False            False         False   False    False
# 249       False            False         False   False    False
#
#      Film Industry  Genre  Director  Box office collection  User reviews  \
# 0            False  False     False                  False         False
# ...
